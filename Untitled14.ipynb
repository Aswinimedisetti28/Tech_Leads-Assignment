# %% [markdown]
# <a href="https://colab.research.google.com/github/Aswinimedisetti28/Tech_Leads-Assignment/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_excel('/content/duplicate_data.xlsx')
duplicate_rows = df[df.duplicated()]

# %%
df
# Out:
#    Roll number  Type of entry                 Name of the Student Branch  \
# 0    21JN1A45A1        REGULAR  Nune Ramya Satya Santhoshi Durga     AID
# 1    21JN1A45A2        REGULAR         chandravanka Satya mohana     AID
# 2    21JN1A45A2        REGULAR         chandravanka Satya mohana     AID
# 3    21JN1A45A3        REGULAR               Palepu.satya sravani    AID
# 4    21JN1A45A4        REGULAR             PERABATTULA SATYAKALA     AID
# ..          ...            ...                                ...    ...
# 72   22JN5A4503            L.E                  Tatapudi Suchitra    AID
# 73   22JN5A4504            L.E    THOTAKURA MOKSHA SAI VISALAKSHI    AID
# 74   22JN5A4505            L.E              vanapalli krupa vathi    AID
# 75   22JN5A4506            L.E                   KANURI VYSHNAVI     AID
# 76   22JN5A4506            L.E                   KANURI VYSHNAVI     AID
#
#    Day scholar /hostler/outside hostel     Section Mobile Number  \
# ...

# %%
df.head(15)
# Out:
#    Roll number  Type of entry                 Name of the Student Branch  \
# 0    21JN1A45A1        REGULAR  Nune Ramya Satya Santhoshi Durga     AID
# 1    21JN1A45A2        REGULAR         chandravanka Satya mohana     AID
# 2    21JN1A45A2        REGULAR         chandravanka Satya mohana     AID
# 3    21JN1A45A3        REGULAR               Palepu.satya sravani    AID
# 4    21JN1A45A4        REGULAR             PERABATTULA SATYAKALA     AID
# 5    21JN1A45A5        REGULAR                GADI .LAKSHMI PRIYA    AID
# 6    21JN1A45A6        REGULAR                Ch.sowrabhya bhanu     AID
# 7    21JN1A45A7        REGULAR      ALAMANDA VEERA VENKATA HARINI    AID
# 8    21JN1A45A8        REGULAR           Burela Vachana Priyanka     AID
# 9    21JN1A45A9        REGULAR                Tillapudi Sowjanya     AID
# 10   21JN1A45B0        REGULAR                     Ravuri.Lavanya    AID
# 11   21JN1A45B0        REGULAR                     Ravuri.Lavanya    AID
# ...

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
#       ...
# 72    False
# 73    False
# 74    False
# 75    False
# 76     True
# Length: 77, dtype: bool

# %%
df = df.drop_duplicates()
df
# Out:
#    Roll number  Type of entry                 Name of the Student Branch  \
# 0    21JN1A45A1        REGULAR  Nune Ramya Satya Santhoshi Durga     AID
# 1    21JN1A45A2        REGULAR         chandravanka Satya mohana     AID
# 3    21JN1A45A3        REGULAR               Palepu.satya sravani    AID
# 4    21JN1A45A4        REGULAR             PERABATTULA SATYAKALA     AID
# 5    21JN1A45A5        REGULAR                GADI .LAKSHMI PRIYA    AID
# ..          ...            ...                                ...    ...
# 71   22JN5A4502            L.E  Mummidi Veera venkata Sri Akshita    AID
# 72   22JN5A4503            L.E                  Tatapudi Suchitra    AID
# 73   22JN5A4504            L.E    THOTAKURA MOKSHA SAI VISALAKSHI    AID
# 74   22JN5A4505            L.E              vanapalli krupa vathi    AID
# 75   22JN5A4506            L.E                   KANURI VYSHNAVI     AID
#
#    Day scholar /hostler/outside hostel     Section Mobile Number  \
# ...

# %%
import pandas as pd
df = pd.read_csv('/content/StudentsPerformance.csv')
df=pd.DataFrame(df)

# %%
df.head(11)
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group B           bachelor's degree      standard
# 1   female        group C                some college      standard
# 2   female        group B             master's degree      standard
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 5   female        group B          associate's degree      standard
# 6   female        group B                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 9   female        group B                 high school  free/reduced
# 10    male        group C          associate's degree      standard
#
#    test preparation course  math score  reading score  writing score
# 0                     none        72.0           72.0            NaN
# ...

# %%
df.isnull()
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0     False           False                        False  False
# 1     False           False                        False  False
# 2     False           False                        False  False
# 3     False           False                        False  False
# 4     False           False                        False  False
# ..      ...             ...                          ...    ...
# 995   False           False                        False  False
# 996   False           False                        False  False
# 997   False           False                        False  False
# 998   False           False                        False  False
# 999   False           False                        False  False
#
#      test preparation course  math score  reading score  writing score
# 0                      False       False          False           True
# ...

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     2
# reading score                  2
# writing score                  2
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 6

# %%
df1=df.fillna(value=0)
df1
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df2=df.fillna(method='pad')
df2
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df3=df.fillna(method='bfill')
df3
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df4=df.fillna(method='pad',axis=1)
df4
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course math score reading score writing score
# 0                      none       72.0          72.0          72.0
# ...

# %%
df5=df.fillna(method='bfill',axis=1)
df5
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course math score reading score writing score
# 0                      none       72.0          72.0           NaN
# ...

# %%
df6=df.fillna({'reading score':3,
               'writing score':5})
df6
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# filling null value with mean

# %%
#df['reading score'].fillna(df['reading score'].mean(), inplace=True)
#df

# %%
df7 = df.copy()


df7['reading score'].fillna(df7['reading score'].mean(), inplace=True)
df7
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df8=df.copy()


df8['reading score'].fillna(df8['reading score'].max(), inplace=True)
df8
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df8=df.copy()


df8['reading score'].fillna(df8['reading score'].min(), inplace=True)
df8
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df9=df.dropna()
df9
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df9=df.dropna(how='any')#all
df9
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.scatter(df['math score'], df['reading score'],df['writing score'])

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.scatter(df['math score'], df['reading score'])
plt.xlabel('Math Score')
plt.ylabel('Reading Score')
plt.show()

# %%
plt.scatter(df['math score'], df['reading score'], c=df['writing score'], cmap='viridis')
plt.xlabel('Math Score')
plt.ylabel('Reading Score')

plt.colorbar(label='Writing Score')
plt.show()

# %%
sns.scatterplot(x='math score', y='reading score', data=df)
plt.xlabel('Math Score')
plt.ylabel('Reading Score')
plt.show()
